# %%
# Data structures
import pandas as pd
import numpy as np

# Misc
import os
import pdb
from sklearn.preprocessing import OrdinalEncoder

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from prettytable import PrettyTable

# %%
datadir='/Users/madelinefrank/Documents/KSU/Course_Work/5_Summer2023/CS_7265/Project/data'
data_fn='ALL_MODEL_DATA.csv'
cols_model = ['DAYOFWEEK','DAYOFYEAR','CARRIER','ORIG','ORIG_ST','DEST',
              'DEST_ST','CRS_HR_DEP','CRS_HR_ARR','DIST_GRP','ARR_DEL15_TF']
cols=['DAYOFWEEK','DAYOFYEAR','CARRIER','ORIG','ORIG_ST','DEST','DEST_ST','CRS_HR_DEP','CRS_HR_ARR','DIST_GRP','ARR_DEL15_TF']
feats=['DAYOFWEEK','DAYOFYEAR','CARRIER','ORIG','ORIG_ST','DEST','DEST_ST','CRS_HR_DEP','CRS_HR_ARR','DIST_GRP']
label=['ARR_DEL15_TF']
dtypes={c: 'uint8' for c in cols if c!='DAYOFYEAR'}
dtypes['DAYOFYEAR']='int16'
dtypes_feats={k: v for k, v in dtypes.items() if k!=label[0]}
airlines=['AA','B6','DL','F9','NK','UA','WN']
oenc_fn='oenc2lbls_AIRPORT'


df=pd.read_csv(os.path.join(datadir,data_fn),index_col=False,dtype=dtypes)

# %%
# Plot Histograms
plt.figure().set_figwidth(11)
#plt.hist(df.DAYOFYEAR,rwidth=0.7,bins=24,align='right',log=True)
plt.hist(df.DAYOFYEAR,rwidth=0.7,bins=24,align='right',log=True)
plt.title('2017-2019 Flights by Day-of-Year')
plt.xlabel('Day of Year')
plt.xticks(ticks=[15,31,46,59,74,90,105,120,135,151,166,181,196,212,227,243,258,273,288,304,319,334,349,365])
plt.show()

# %%
plt.figure().set_figwidth(8)
lbls, cts = np.unique(df.DIST_GRP.to_numpy(copy=True), return_counts=True)
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls,labels=['<250',f'250-\n499',f'500-\n749',f'750-\n999',f'1000-\n1249',f'1250-\n1499',f'1500-\n1749',f'1750-\n1999',f'2000-\n2249',f'2250-\n2499',f'2500+'])
plt.title('2017-2019 Flights by Planned Travel Distance')
plt.xlabel('Planned Route Distance (in miles)')
plt.show()

# %%
DF2017.DAYOFYEAR.value_counts()
# Out:
# 330    12285
# 212    12101
# 180    12098
# 208    12092
# 181    12073
#        ...
# 35      8204
# 14      7996
# 252     7502
# 7       7369
# 327     7062
# Name: DAYOFYEAR, Length: 365, dtype: int64

# %%
del df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12

# %%
del DF2017,DF2018

# %%
# Plot Histograms
lbls, cts = np.unique(df.DAYOFWEEK.to_numpy(copy=True), return_counts=True)
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls,labels=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.title('2017-2019 Flights per Day-of-Week')
plt.ylim(bottom=1.4e6,top=1.85e6)
plt.yscale('log')
# plt.annotate('444 (65%)',(-0.2,415))
# plt.annotate('239 (35%)',(0.9,205))
plt.show()



# plt.hist(df.CARRIER,rwidth=0.7,align='mid')
# plt.title('Carrier')
# plt.xlabel('Day of Week')
# plt.show()

lbls, cts = np.unique(df.CARRIER.to_numpy(copy=True), return_counts=True)
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('2017-2019 Flights by Carrier (Airline)')
# plt.annotate('444 (65%)',(-0.2,415))
# plt.annotate('239 (35%)',(0.9,205))
plt.show()

# %%
plt.figure().set_figwidth(20)
lbls, cts = np.unique(df.ORIG.to_numpy(copy=True), return_counts=True)

idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls[:25], cts[:25], align='center')
plt.gca().set_xticks(ticks=lbls[:25])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Origin Airport')
# plt.yscale('log')
b,t=plt.ylim()
plt.show()

# %%
plt.figure().set_figwidth(10)
lbls, cts = np.unique(df.ORIG.to_numpy(copy=True), return_counts=True)
tmp=pd.read_csv(os.path.join(datadir,'oenc2lbls_AIRPORT.csv'),header=None,index_col=False,dtype={0:'uint8'})
tmp=tmp.to_dict()
tmp=dict(zip(tmp[0].values(),tmp[1].values()))
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
Lbls=[tmp[x] for x in lbls]


plt.bar(Lbls[:20], cts[:20], align='center')
plt.title('Flights by Origin Airport')
#plt.yscale('log')
b,t=plt.ylim()
plt.show()

# %%
lbls==key
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True])

# %%
plt.figure().set_figwidth(15)
lbls, cts = np.unique(df.ORIG_ST.to_numpy(copy=True), return_counts=True)
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls)#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Origin State')
plt.yscale('log')
b,t=plt.ylim()
plt.show()

# %%
plt.figure().set_figwidth(15)
lbls, cts = np.unique(df.DEST.to_numpy(copy=True), return_counts=True)
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls[:25], cts[:25], align='center')
plt.gca().set_xticks(ticks=lbls[:25])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Destination Airport')
# plt.yscale('log')
b,t=plt.ylim()
plt.show()

plt.figure().set_figwidth(20)
plt.bar(lbls[25:50], cts[25:50], align='center')
plt.gca().set_xticks(ticks=lbls[25:50])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Destination Airport')
# plt.yscale('log')
plt.ylim(b,t)
plt.show()

plt.figure().set_figwidth(20)
plt.bar(lbls[50:75], cts[50:75], align='center')
plt.gca().set_xticks(ticks=lbls[50:75])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Destination Airport')
# plt.yscale('log')
plt.ylim(b,t)
plt.show()

plt.figure().set_figwidth(20)
plt.bar(lbls[75:], cts[75:], align='center')
plt.gca().set_xticks(ticks=lbls[75:])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Destination Airport')
# plt.yscale('log')
plt.ylim(b,t)
plt.show()

plt.figure().set_figwidth(20)
lbls, cts = np.unique(df.DEST_ST.to_numpy(copy=True), return_counts=True)
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls)#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Destination State')
plt.yscale('log')
plt.show()

# %%
plt.figure().set_figwidth(15)
lbls, cts = np.unique(df.CRS_HR_DEP.to_numpy(copy=True), return_counts=True)
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls[:25], cts[:25], align='center',width=0.7)
plt.gca().set_xticks(ticks=lbls[:25])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Planned Hour of Departure')
#plt.yscale('log')
# b,t=plt.ylim()
plt.show()

plt.figure().set_figwidth(15)
lbls, cts = np.unique(df.CRS_HR_ARR.to_numpy(copy=True), return_counts=True)
idx=np.reshape(np.flipud(np.reshape(np.argsort(cts),(-1,1))),-1)
lbls=lbls[idx]
cts=cts[idx]
plt.bar(lbls[:25], cts[:25], align='center',width=0.7)
plt.gca().set_xticks(ticks=lbls[:24])#,labels=['American','JetBlue','Delta','Frontier','Spirit','United','Southwest'])
plt.title('Flights by Planned Hour of Arrival')
# plt.yscale('log')
# b,t=plt.ylim()
plt.show()

# %%
df=df.loc[(df['ORIG']!='SBA' | df['DEST']!='SBA')]
# Out:
#            YR  MON  DAYOFMONTH  DAYOFWEEK  DAYOFYEAR CARRIER ORIG ORIG_ST  \
# 0        2017    9           1          5        244      AA  ABQ      NM
# 1        2017    9           1          5        244      AA  ABQ      NM
# 2        2017    9           1          5        244      AA  ABQ      NM
# 3        2017    9           1          5        244      AA  ABQ      NM
# 4        2017    9           1          5        244      AA  ABQ      NM
# ...       ...  ...         ...        ...        ...     ...  ...     ...
# 4126849  2018    8          31          5        243      WN  TUS      AZ
# 4126850  2018    8          31          5        243      WN  TUS      AZ
# 4126851  2018    8          31          5        243      WN  TUS      AZ
# 4126852  2018    8          31          5        243      WN  TUS      AZ
# 4126853  2018    8          31          5        243      WN  TUS      AZ
#
#         DEST DEST_ST  ...  ARR_DEL_GRP  CRS_T_ELAPSED  ACT_T_ELAPSED  DIST  \
# ...

# %%
df=df.loc[(~df['ORIG'].isin(['SBA']) & ~df['DEST'].isin(['SBA']))]

# %%
# Make violin plots to show counts of values for each feature and how they are distributed for
# cases that are benign and cases that are malignant
plt.figure().set_figwidth(20)
sns.catplot(x = 'ARR_DEL15_TF', y = 'MON',data=df[['MON','ARR_DEL15_TF']],kind="violin")
plt.title('Delays by Month')
plt.xticks(ticks=[0,1],labels=['Not Delayed','Delayed'])
plt.show()

plt.figure().set_figwidth(20)
sns.catplot(x = 'ARR_DEL15_TF', y = 'DAYOFWEEK',data=df[['DAYOFWEEK','ARR_DEL15_TF']],kind="violin")
plt.title('Delays by Day of Week')
plt.xticks(ticks=[0,1],labels=['Not Delayed','Delayed'])
plt.show()

# %%
sns.catplot(x = 'ARR_DEL15_TF', y = 'CRS_HR_DEP',data=df[['CRS_HR_DEP','ARR_DEL15_TF']],kind="violin")
plt.title('Delays by Planned Hour of Departure')
plt.xticks(ticks=[0,1],labels=['Not Delayed','Delayed'])
plt.show()

sns.catplot(x = 'ARR_DEL15_TF', y = 'CRS_HR_ARR',data=df[['CRS_HR_ARR','ARR_DEL15_TF']],kind="violin")
plt.title('Delays by Planned Hour of Arrival')
plt.xticks(ticks=[0,1],labels=['Not Delayed','Delayed'])
plt.show()

# %%
lbls, cts = np.unique(df.ARR_DEL15_TF.to_numpy(copy=True), return_counts=True)
p0=round((cts[0]/sum(cts))*100,3)
p1=round((cts[1]/sum(cts))*100,3)
plt.bar(lbls, cts, align='center')
plt.gca().set_xticks(ticks=lbls,labels=['OnTime','Delayed'])
plt.title('Data Imbalance: Distribution of OnTime and Delayed Flights')
plt.annotate(f'{p0}%',(-0.1,0.8e7))
plt.annotate(f'{p1}%',(0.9,0.15e7))
plt.show()
